# %%
from pyspark.sql import SparkSession
from delta import *
import os

# %%
def create_spark_session():
    """
    Creates a SparkSession with Delta Lake and S3/MinIO configurations.
    """
    builder = SparkSession.builder \
        .appName("EnterpriseLakehouseInit") \
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
        .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
        .config("spark.hadoop.fs.s3a.access.key", "minioadmin") \
        .config("spark.hadoop.fs.s3a.secret.key", "minioadmin") \
        .config("spark.hadoop.fs.s3a.path.style.access", "true") \
        .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
        .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
        .config("spark.sql.warehouse.dir", "s3a://warehouse/")

    # Add required Maven packages for Delta + AWS S3
    # Note: Versions must be compatible with the Spark version in the Dockerfile (3.5.0)
    return configure_spark_with_delta_pip(builder, extra_packages=[
        "org.apache.hadoop:hadoop-aws:3.3.4",
        "com.amazonaws:aws-java-sdk-bundle:1.12.262"
    ]).getOrCreate()

# %%
spark = create_spark_session()

# %%
def write_table(spark, table_name, df, write_mode="overwrite"):
    spark.conf.set("spark.databricks.delta.clusteredTable.enableClusteringTablePreview", "false")
    table_path = f"s3a://warehouse/{table_name}"
    print(f"Writing Delta table to {table_path}...")
    df.write.format("delta").mode(write_mode).save(table_path)
    spark.sql(f"CREATE TABLE IF NOT EXISTS {table_name} USING DELTA LOCATION '{table_path}'")
    print(f"Table {table_name} created successfully.")

def write_clustered_table(spark, table_name, df, write_mode="overwrite"):
    spark.conf.set("spark.databricks.delta.clusteredTable.enableClusteringTablePreview", "true")
    table_path = f"s3a://warehouse/{table_name}"
    if write_mode == "overwrite":
        spark.sql(f"CREATE TABLE IF NOT EXISTS {table_name}(id long, name string, department string, hire_date string) USING DELTA CLUSTER BY (name, department) LOCATION '{table_path}'")
    print(f"Writing Delta table to {table_path}...")
    df.write.format("delta").option("clusteringColumns", "name, department").mode(write_mode).save(table_path)
    print(f"Table {table_name} created successfully.")

# %%
def print_table(spark, table_name):
    print("\n--- Verifying Data via SQL ---")
    df = spark.sql(f"SELECT * FROM {table_name}")
    df.show(df.count())

def print_delta_history(spark, table_name):
    print("\n--- Verifying Delta History ---")
    from delta.tables import DeltaTable
    dt = DeltaTable.forPath(spark, f"s3a://warehouse/{table_name}")
    dt.history().show()

def optimize_table(spark, table_name):
    print("\n--- Optimizing table via SQL ---")
    spark.sql(f"OPTIMIZE {table_name}")

def vacuum_files(spark, table_name):
    print("\n--- Vacuuming files up ---")
    spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "false")
    from delta.tables import DeltaTable
    dt = DeltaTable.forPath(spark, f"s3a://warehouse/{table_name}")
    dt.vacuum(retentionHours=0)

# %%
# Define table name
table_name = "test21"

# Define data schema
columns = ["id", "name", "department", "hire_date"]

# Define DF-1
data1 = [
    (1, "Alice", "Engineering", "2023-01-01"),
    (2, "Bob", "Sales", "2023-01-02"),
    (3, "Charlie", "Marketing", "2023-01-03")
]
df1 = spark.createDataFrame(data1, columns)

write_clustered_table(spark, table_name, df1)
for i in range(3,600,3):
    # Define DF-2
    data2 = [
        (i+1, "Alice", "Engineering-Team", "2023-01-01"),
        (i+2, "Charlie", "Flight", "2023-01-02"),
        (i+3, "Charlie", "Marketing", "2023-01-03")
    ]
    df2 = spark.createDataFrame(data2, columns)
    write_clustered_table(spark, table_name, df2, write_mode="append")

optimize_table(spark, table_name)
vacuum_files(spark, table_name)
print_table(spark, table_name)
print_delta_history(spark, table_name)
# Out:
# --- Verifying Data via SQL ---
# +---+-------+----------------+----------+
# | id|   name|      department| hire_date|
# +---+-------+----------------+----------+
# | 34|  Alice|Engineering-Team|2023-01-01|
# | 49|  Alice|Engineering-Team|2023-01-01|
# | 31|  Alice|Engineering-Team|2023-01-01|
# | 55|  Alice|Engineering-Team|2023-01-01|
# |  7|  Alice|Engineering-Team|2023-01-01|
# | 19|  Alice|Engineering-Team|2023-01-01|
# | 22|  Alice|Engineering-Team|2023-01-01|
# | 16|  Alice|Engineering-Team|2023-01-01|
# | 28|  Alice|Engineering-Team|2023-01-01|
# | 37|  Alice|Engineering-Team|2023-01-01|
# | 25|  Alice|Engineering-Team|2023-01-01|
# |  4|  Alice|Engineering-Team|2023-01-01|
# | 58|  Alice|Engineering-Team|2023-01-01|
# | 52|  Alice|Engineering-Team|2023-01-01|
# | 46|  Alice|Engineering-Team|2023-01-01|
# | 40|  Alice|Engineering-Team|2023-01-01|
# | 43|  Alice|Engineering-Team|2023-01-01|
# | 13|  Alice|Engineering-Team|2023-01-01|
# | 10|  Alice|Engineering-Team|2023-01-01|
# |  1|  Alice|     Engineering|2023-01-01|
# | 60|Charlie|       Marketing|2023-01-03|
# | 36|Charlie|       Marketing|2023-01-03|
# | 39|Charlie|       Marketing|2023-01-03|
# | 12|Charlie|       Marketing|2023-01-03|
# | 54|Charlie|       Marketing|2023-01-03|
# | 24|Charlie|       Marketing|2023-01-03|
# | 51|Charlie|       Marketing|2023-01-03|
# | 15|Charlie|       Marketing|2023-01-03|
# | 27|Charlie|       Marketing|2023-01-03|
# | 18|Charlie|       Marketing|2023-01-03|
# |  9|Charlie|       Marketing|2023-01-03|
# | 48|Charlie|       Marketing|2023-01-03|
# | 57|Charlie|       Marketing|2023-01-03|
# | 33|Charlie|       Marketing|2023-01-03|
# |  3|Charlie|       Marketing|2023-01-03|
# | 21|Charlie|       Marketing|2023-01-03|
# |  6|Charlie|       Marketing|2023-01-03|
# | 45|Charlie|       Marketing|2023-01-03|
# | 30|Charlie|       Marketing|2023-01-03|
# | 42|Charlie|       Marketing|2023-01-03|
# | 23|Charlie|          Flight|2023-01-02|
# | 29|Charlie|          Flight|2023-01-02|
# | 44|Charlie|          Flight|2023-01-02|
# | 53|Charlie|          Flight|2023-01-02|
# | 41|Charlie|          Flight|2023-01-02|
# | 32|Charlie|          Flight|2023-01-02|
# |  8|Charlie|          Flight|2023-01-02|
# | 11|Charlie|          Flight|2023-01-02|
# | 47|Charlie|          Flight|2023-01-02|
# |  5|Charlie|          Flight|2023-01-02|
# | 56|Charlie|          Flight|2023-01-02|
# | 59|Charlie|          Flight|2023-01-02|
# | 17|Charlie|          Flight|2023-01-02|
# | 26|Charlie|          Flight|2023-01-02|
# | 38|Charlie|          Flight|2023-01-02|
# | 50|Charlie|          Flight|2023-01-02|
# | 20|Charlie|          Flight|2023-01-02|
# | 14|Charlie|          Flight|2023-01-02|
# | 35|Charlie|          Flight|2023-01-02|
# |  2|    Bob|           Sales|2023-01-02|
# +---+-------+----------------+----------+
#
#
# --- Verifying Delta History ---
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |version|           timestamp|userId|userName|operation| operationParameters| job|notebook|clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |     21| 2026-01-26 17:09:34|  NULL|    NULL| OPTIMIZE|{predicate -> [],...|NULL|    NULL|     NULL|         20|SnapshotIsolation|        false|{numRemovedFiles ...|        NULL|Apache-Spark/3.5....|
# |     20| 2026-01-26 17:09:31|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         19|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     19| 2026-01-26 17:09:30|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         18|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     18| 2026-01-26 17:09:29|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         17|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     17| 2026-01-26 17:09:27|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         16|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     16| 2026-01-26 17:09:26|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         15|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     15| 2026-01-26 17:09:25|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         14|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     14| 2026-01-26 17:09:24|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         13|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     13| 2026-01-26 17:09:23|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         12|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     12| 2026-01-26 17:09:22|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         11|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     11| 2026-01-26 17:09:20|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|         10|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |     10| 2026-01-26 17:09:18|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          9|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      9| 2026-01-26 17:09:17|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          8|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      8| 2026-01-26 17:09:16|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          7|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      7| 2026-01-26 17:09:15|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          6|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      6| 2026-01-26 17:09:14|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          5|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      5|2026-01-26 17:09:...|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          4|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      4| 2026-01-26 17:09:12|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          3|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      3| 2026-01-26 17:09:11|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          2|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# |      2| 2026-01-26 17:09:10|  NULL|    NULL|    WRITE|{mode -> Append, ...|NULL|    NULL|     NULL|          1|     Serializable|         true|{numFiles -> 4, n...|        NULL|Apache-Spark/3.5....|
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# only showing top 20 rows
